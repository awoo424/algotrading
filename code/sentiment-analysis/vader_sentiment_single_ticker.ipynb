# %%
import os 
import pandas as pd

from sklearn.model_selection import train_test_split
import numpy as np
dir_name= os.getcwd()+'/data/'

# %%
# get data for hkex equity stock
hkex_files=os.path.join(dir_name,'stock_ticker_datasets/hkex_in.csv')

hkex=pd.read_csv(hkex_files)

hkex['Ticker']=hkex['Ticker'].astype(str)
hkex_input=hkex['Ticker']

n = 400  #chunk row size
hkex_df = [hkex_input[i:i+n] for i in range(0,hkex_input.shape[0],n)]

hkex.set_index("Ticker" , inplace=True)
print(hkex.head())
# Out:
#         Unnamed: 0                      Description
# Ticker
# 1                0       Cheung Kong (Holdings) Ltd
# 2                1                 CLP Holdings Ltd
# 3                2  Hong Kong and China Gas Co. Ltd
# 4                3             Wharf (Holdings) Ltd
# 5                4                HSBC Holdings plc

# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import twitter_samples 

analyzer = SentimentIntensityAnalyzer()

# %%
# append the compound vader score to the corresponding news
def read_news_path(df):
    print('read in datasets')
    cs=[]
    # append a compound score to every news row
    for row in range(len(df)):
        cs.append(analyzer.polarity_scores(df['news'].iloc[row])['compound'])
    # append the column to original dataset
    df['compound_vader_score']=cs
    return df


# group by the mean compound vader score by dates
def find_news_pred_label(df,threshold):
    print('find_pred_label')
    news=df['news']
    # group the data by dates
    df=df.groupby(['dates'])['compound_vader_score'].mean().reset_index()
    final_label=[]
    # convert the vader score using a threshold to a sentiment label
    for i in range(len(df)):

        if df['compound_vader_score'].iloc[i]>threshold:
            final_label.append(2)
        elif df['compound_vader_score'].iloc[i]<-threshold:
            final_label.append(0)
        elif (df['compound_vader_score'].iloc[i]>=-threshold  
              and df['compound_vader_score'].iloc[i]<=threshold):
            final_label.append(1)

    df['vader_label']=final_label
    return df


# merge the dataset with the hang seng index daily moving average
def merge_actual_label (df,hsi_movement_df):
    print('merge_actual_label')
    vader_data=df
    vader_data.set_index(keys = ["dates"],inplace=True)
    label_data=pd.read_csv(hsi_movement_df)
    label_data.set_index(keys = ["dates"],inplace=True)
    # inner join the two datasets using the date index
    merge=pd.merge(vader_data,label_data, how='inner', left_index=True, right_index=True)
    merge=merge.reset_index()
    # drop the redudant column 
    merge=merge.drop(['Unnamed: 0'],axis=1)
    return merge

# %%
def starter_vader(ticker):
    # get the full path of each ticker
    path=os.path.join(dir_name,'data-news/data-aastock/'+'data-'+ticker.zfill(5)+'-aastock.csv')           
    df=pd.read_csv(path,names=['dates','news'])
    # read append the compound vader score to the pandas dataframe
    df=read_news_path(df)
    # pass in the threshold to get the vader label
    df=find_news_pred_label(df,0.01)
            
    result_path=os.path.join(dir_name,'data-results/hkex-results/hkex-aastock/'+'data-'+ticker.zfill(5)+'-result.csv') 
    # get the full path of the hang seng index average csv file
    hsi_moement_path=os.path.join(dir_name,'train-data/hkex/hsi_movement.csv')  
    # merge the df pandas with the hsi_average
    df=merge_actual_label (df,hsi_movement_path)
    # store to the csv file if the dataset is not empty
    if(df.empty==False):
        df.to_csv(result_path,index=False)

# collect vader label for tickers in hkex    
for tickers in hkex_df:
     for ticker in tickers:
            starter_vader(ticker)
# Out:
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-12-18                0.4995            2    -0.005699
# 1  2020-12-22                0.0000            1    -0.005389
# 2  2020-12-24                0.0000            1     0.001659
# 3  2020-12-28                0.4215            2     0.000999
# 4  2020-12-29                0.2023            2     0.002946
# 5  2020-12-31                0.3824            2     0.001336
# 6  2021-01-08                0.1591            2     0.008983
# 7  2021-01-11                0.5267            2    -0.003420
# 8  2021-01-12                0.5859            2     0.013711
# 9  2021-01-19                0.4466            2     0.018629
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-10-29                0.0516            2     0.012210
# 1  2020-11-09                0.2023            2    -0.005413
# 2  2020-11-10                0.0683            2    -0.006518
# 3  2020-11-11                0.8442            2     0.000007
# 4  2020-11-24                0.1480            2    -0.001582
# 5  2020-11-30                0.2960            2    -0.019063
# 6  2021-01-19                0.0000            1     0.018629
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-10-27                 0.000            1    -0.002125
# 1  2020-11-12                 0.000            1    -0.009086
# 2  2020-11-24                 0.148            2    -0.001582
# 3  2020-12-11                 0.000            1    -0.004819
# 4  2020-12-18                 0.000            1    -0.005699
# 5  2021-01-04                 0.296            2     0.014238
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-12-28              0.000000            1     0.000999
# 1  2020-12-29              0.000000            1     0.002946
# 2  2021-01-05              0.157980            2     0.013508
# 3  2021-01-08              0.380833            2     0.008983
# 4  2021-01-13              0.000000            1    -0.002604
# 5  2021-01-27              0.296000            2    -0.008765
# 6  2021-02-05              0.000000            1    -0.000560
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-25               0.00000            1     0.016232
# 1  2021-01-26               0.05848            2    -0.016780
# 2  2021-01-27               0.13770            2    -0.008765
# 3  2021-01-28               0.00000            1    -0.012591
# 4  2021-01-29               0.00000            1    -0.018819
# 5  2021-02-01               0.45880            2     0.015286
# 6  2021-02-02               0.00000            1    -0.004405
# 7  2021-02-03               0.29600            2     0.000070
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-09-08               0.45460            2    -0.006493
# 1  2020-10-14               0.34700            2    -0.005714
# 2  2020-11-10               0.45460            2    -0.006518
# 3  2020-11-24               0.59555            2    -0.001582
# 4  2021-02-05               0.34700            2    -0.000560
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-10-09              0.332633            2    -0.009229
# 1  2020-10-15              0.446600            2    -0.015294
# 2  2020-11-11              0.446600            2     0.000007
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-10-29                0.2233            2     0.012210
# 1  2020-11-12                0.3470            2    -0.009086
# 2  2020-11-26                0.3774            2     0.004652
# 3  2021-01-11                0.3400            2    -0.003420
# 4  2021-02-01                0.0000            1     0.015286
# 5  2021-02-05               -0.1591            0    -0.000560
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-09-11              0.296000            2     0.006187
# 1  2020-11-20              0.000000            1     0.001692
# 2  2020-12-30              0.482400            2     0.016932
# 3  2021-01-28              0.347175            2    -0.012591
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-12-03               0.00000            1     0.003947
# 1  2020-12-04               0.00000            1     0.000907
# 2  2020-12-07               0.00000            1    -0.013536
# 3  2020-12-10               0.24695            2     0.002860
# 4  2020-12-18               0.29600            2    -0.005699
# 5  2021-01-04               0.20230            2     0.014238
# 6  2021-01-07               0.44040            2    -0.006041
# 7  2021-01-12              -0.15910            0     0.013711
# 8  2021-01-21               0.29600            2    -0.000802
# 9  2021-02-02               0.00000            1    -0.004405
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-12-31              0.000000            1     0.001336
# 1  2021-01-05              0.000000            1     0.013508
# 2  2021-01-08              0.329267            2     0.008983
# 3  2021-01-13              0.648600            2    -0.002604
# 4  2021-01-25              0.170200            2     0.016232
# 5  2021-01-26              0.051600            2    -0.016780
# 6  2021-01-27              0.000000            1    -0.008765
# 7  2021-01-29              0.000000            1    -0.018819
# 8  2021-02-05              0.000000            1    -0.000560
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-12-03               0.00000            1     0.003947
# 1  2020-12-29               0.00000            1     0.002946
# 2  2021-01-05               0.20212            2     0.013508
# 3  2021-01-08               0.38640            2     0.008983
# 4  2021-01-13               0.00000            1    -0.002604
# 5  2021-01-25               0.00000            1     0.016232
# 6  2021-01-27               0.29600            2    -0.008765
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-12-18               0.10115            2    -0.005699
# 1  2020-12-21               0.29600            2    -0.004388
# 2  2020-12-29               0.00000            1     0.002946
# 3  2020-12-31               0.00000            1     0.001336
# 4  2021-01-05               0.12972            2     0.013508
# 5  2021-01-13               0.51060            2    -0.002604
# 6  2021-01-25               0.00000            1     0.016232
# 7  2021-01-27               0.29600            2    -0.008765
# 8  2021-02-05               0.00000            1    -0.000560
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-12-29               0.00000            1     0.002946
# 1  2021-01-05               0.01965            2     0.013508
# 2  2021-01-06               0.64860            2     0.002860
# 3  2021-01-12               0.00000            1     0.013711
# 4  2021-01-13               0.06105            2    -0.002604
# 5  2021-01-25               0.00000            1     0.016232
# 6  2021-01-26               0.00000            1    -0.016780
# 7  2021-01-27               0.28595            2    -0.008765
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-08-10                 0.296            2     0.000025
# 1  2020-08-11                 0.000            1     0.009271
# 2  2021-01-05                 0.296            2     0.013508
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-26                0.1806            2     0.004652
# 1  2020-11-30                0.2500            2    -0.019063
# 2  2020-12-07                0.0000            1    -0.013536
# 3  2020-12-14                0.2960            2    -0.004999
# 4  2020-12-18                0.2960            2    -0.005699
# 5  2020-12-30                0.0000            1     0.016932
# 6  2021-01-05                0.1480            2     0.013508
# 7  2021-01-29               -0.2263            0    -0.018819
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-12-03              0.098667            2     0.003947
# 1  2020-12-07              0.202300            2    -0.013536
# 2  2020-12-10              0.440400            2     0.002860
# 3  2020-12-18              0.000000            1    -0.005699
# 4  2021-01-07              0.000000            1    -0.006041
# 5  2021-01-12              0.148000            2     0.013711
# 6  2021-02-01              0.177900            2     0.015286
# 7  2021-02-02              0.000000            1    -0.004405
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-08-21               0.14800            2     0.004267
# 1  2020-09-21               0.29600            2    -0.021778
# 2  2020-09-23               0.00000            1     0.001746
# 3  2020-09-24               0.07400            2    -0.009634
# 4  2020-12-22               0.39775            2    -0.005389
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-19              0.148750            2     0.018629
# 1  2021-01-21             -0.159100            0    -0.000802
# 2  2021-01-22              0.025800            2    -0.012123
# 3  2021-01-25             -0.296000            0     0.016232
# 4  2021-01-26              0.448850            2    -0.016780
# 5  2021-01-27              0.000000            1    -0.008765
# 6  2021-01-28              0.000000            1    -0.012591
# 7  2021-02-01             -0.329267            0     0.015286
# 8  2021-02-02              0.296000            2    -0.004405
# 9  2021-02-05              0.440400            2    -0.000560
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-17                 0.296            2    -0.003771
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-09-18                 0.296            2     0.003047
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-08-06                0.4466            2    -0.010748
# 1  2020-08-20                0.4466            2    -0.010535
# 2  2020-09-30                0.4466            2    -0.003815
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-27                   0.0            1      0.00509
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-26                 0.296            2     0.004652
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-07-17                0.7034            2    -0.002104
# 1  2020-07-21                0.7034            2     0.008204
# 2  2020-07-24                0.1480            2    -0.013395
# 3  2020-07-28                0.7925            2    -0.006815
# 4  2020-08-27                0.7925            2    -0.007406
# 5  2020-10-05                0.7925            2    -0.011299
# 6  2020-10-07                0.0000            1     0.010128
# 7  2021-01-04                0.7925            2     0.014238
# 8  2021-01-25                0.5106            2     0.016232
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-08-06              0.197333            2    -0.010748
# 1  2020-11-03              0.296000            2     0.010133
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-07-27                0.0000            1    -0.012312
# 1  2020-08-03                0.4466            2    -0.004424
# 2  2020-08-25                0.0000            1    -0.003938
# 3  2020-09-15               -0.8020            0     0.004513
# 4  2020-09-30                0.0000            1    -0.003815
# 5  2021-02-01                0.1280            2     0.015286
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#          dates  compound_vader_score  vader_label  hsi_average
# 0   2020-10-15                0.2500            2    -0.015294
# 1   2020-10-22                0.0000            1     0.003637
# 2   2020-11-02                0.0000            1     0.007628
# 3   2020-11-05                0.0000            1     0.007647
# 4   2020-11-09                0.3818            2    -0.005413
# 5   2020-12-02                0.0000            1    -0.005157
# 6   2020-12-28                0.0000            1     0.000999
# 7   2021-01-11                0.0000            1    -0.003420
# 8   2021-01-25                0.0258            2     0.016232
# 9   2021-01-26                0.0000            1    -0.016780
# 10  2021-01-29                0.0000            1    -0.018819
# 11  2021-02-01                0.0000            1     0.015286
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-09-15                0.2960            2     0.004513
# 1  2020-09-30               -0.5574            0    -0.003815
# 2  2020-11-11                0.5719            2     0.000007
# 3  2020-11-27                0.1480            2     0.005090
# 4  2020-12-08               -0.8020            0    -0.005888
# 5  2021-02-01                0.2960            2     0.015286
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-10-29                 0.296            2      0.01221
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-25                 0.000            1    -0.005601
# 1  2020-12-15                 0.000            1    -0.008011
# 2  2020-12-31                 0.296            2     0.001336
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-20              0.051200            2     0.005641
# 1  2021-01-22              0.000000            1    -0.012123
# 2  2021-01-25              0.304167            2     0.016232
# 3  2021-01-26              0.114700            2    -0.016780
# 4  2021-01-27              0.285950            2    -0.008765
# 5  2021-01-28              0.000000            1    -0.012591
# 6  2021-02-01              0.148000            2     0.015286
# 7  2021-02-05             -0.296000            0    -0.000560
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-09-09                0.1480            2     0.007142
# 1  2020-09-16                0.2732            2    -0.003961
# 2  2020-11-11                0.2960            2     0.000007
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-10-08                0.0258            2    -0.002884
# 1  2020-11-16                0.7603            2     0.000743
# 2  2021-01-25                0.7034            2     0.016232
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-07-20                 0.296            2     0.001534
# 1  2020-08-19                 0.296            2    -0.007103
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-02-03                0.2023            2      0.00007
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-25                0.4939            2    -0.005601
# 1  2020-12-15                0.2960            2    -0.008011
# 2  2020-12-31                0.2960            2     0.001336
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-07-21                0.4404            2     0.008204
# 1  2020-07-28                0.0000            1    -0.006815
# 2  2020-08-26                0.2960            2    -0.001121
# 3  2020-10-29                0.2960            2     0.012210
# 4  2020-11-11                0.2960            2     0.000007
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-20                0.5423            2     0.001692
# 1  2020-12-08                0.0000            1    -0.005888
# 2  2020-12-22                0.0000            1    -0.005389
# 3  2021-01-06                0.0000            1     0.002860
# 4  2021-01-12                0.4466            2     0.013711
# 5  2021-01-19                0.0000            1     0.018629
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-17                0.4466            2    -0.003771
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-12-11              0.000000            1    -0.004819
# 1  2020-12-29              0.000000            1     0.002946
# 2  2021-01-05              0.197475            2     0.013508
# 3  2021-01-08              0.380833            2     0.008983
# 4  2021-01-13              0.226750            2    -0.002604
# 5  2021-01-22              0.510600            2    -0.012123
# 6  2021-01-25              0.000000            1     0.016232
# 7  2021-01-26              0.000000            1    -0.016780
# 8  2021-01-27              0.000000            1    -0.008765
# 9  2021-02-01              0.296000            2     0.015286
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-07-21                 0.000            1     0.008204
# 1  2020-07-28                 0.296            2    -0.006815
# 2  2020-07-31                 0.000            1    -0.006140
# 3  2021-01-04                 0.296            2     0.014238
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-09-16                  0.34            2    -0.003961
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-16               -0.3182            0     0.000743
# 1  2020-11-17                0.0000            1    -0.003771
# 2  2021-02-01                0.2500            2     0.015286
# 3  2021-02-02                0.2960            2    -0.004405
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-10               0.29600            2    -0.006518
# 1  2020-12-30               0.03485            2     0.016932
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-26                 0.000            1     0.004652
# 1  2021-01-26                 0.296            2    -0.016780
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-20                0.8208            2     0.001692
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-08-21                 0.000            1     0.004267
# 1  2020-09-29                 0.296            2    -0.013105
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-13                0.0000            1    -0.002604
# 1  2021-01-21                0.0000            1    -0.000802
# 2  2021-01-25                0.2103            2     0.016232
# 3  2021-01-27                0.4824            2    -0.008765
# 4  2021-01-28                0.0529            2    -0.012591
# 5  2021-01-29                0.0740            2    -0.018819
# 6  2021-02-04               -0.4215            0     0.000686
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-17                0.4466            2    -0.003771
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-14                 0.296            2     0.003124
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-11                 0.296            2     0.000007
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-11                 0.296            2     0.000007
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-09-29                0.4466            2    -0.013105
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-12                 0.296            2    -0.009086
# 1  2020-11-26                 0.296            2     0.004652
# 2  2020-12-11                 0.296            2    -0.004819
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-07-21                 0.000            1     0.008204
# 1  2020-07-28                 0.296            2    -0.006815
# 2  2020-07-31                 0.296            2    -0.006140
# 3  2020-08-27                 0.000            1    -0.007406
# 4  2021-01-04                 0.296            2     0.014238
# 5  2021-02-02                 0.000            1    -0.004405
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-12                0.0000            1    -0.009086
# 1  2021-01-06                0.4466            2     0.002860
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-08                 0.000            1     0.008983
# 1  2021-01-22                 0.296            2    -0.012123
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-12-11              -0.42150            0    -0.004819
# 1  2020-12-22               0.00000            1    -0.005389
# 2  2021-01-04              -0.27365            0     0.014238
# 3  2021-01-06              -0.22630            0     0.002860
# 4  2021-01-19              -0.11315            0     0.018629
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-12-18                0.3400            2    -0.005699
# 1  2021-01-07                0.0000            1    -0.006041
# 2  2021-01-25                0.4033            2     0.016232
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-12              0.547300            2    -0.009086
# 1  2020-11-25              0.085700            2    -0.005601
# 2  2020-12-23              0.282525            2     0.009968
# 3  2020-12-24              0.000000            1     0.001659
# 4  2021-01-13              0.000000            1    -0.002604
# 5  2021-01-27              0.213900            2    -0.008765
# 6  2021-01-28              0.616600            2    -0.012591
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-13                0.1027            2     0.001618
# 1  2021-02-03                0.2960            2     0.000070
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-10-28              0.480500            2    -0.002613
# 1  2020-11-09              0.576600            2    -0.005413
# 2  2020-11-20              0.290867            2     0.001692
# 3  2020-12-02              0.000000            1    -0.005157
# 4  2021-01-13              0.296000            2    -0.002604
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-10-12               0.00000            1     0.017856
# 1  2020-10-16               0.29600            2     0.007951
# 2  2020-11-10               0.00000            1    -0.006518
# 3  2021-01-05               0.37725            2     0.013508
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-05                0.4707            2     0.013508
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-09-04                 0.296            2     0.001080
# 1  2021-02-04                 0.000            1     0.000686
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-10-07                 0.296            2     0.010128
# 1  2020-12-04                 0.000            1     0.000907
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-12-22                0.3313            2    -0.005389
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-19              0.000000            1    -0.003917
# 1  2020-12-09              0.197333            2    -0.000286
# 2  2020-12-14              0.000000            1    -0.004999
# 3  2020-12-15              0.000000            1    -0.008011
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-26                0.2233            2     0.004652
# 1  2020-11-27                0.0000            1     0.005090
# 2  2020-12-18                0.3818            2    -0.005699
# 3  2020-12-22                0.4466            2    -0.005389
# 4  2020-12-28                0.4019            2     0.000999
# 5  2021-01-13                0.0000            1    -0.002604
# 6  2021-01-25                0.0000            1     0.016232
# 7  2021-01-26                0.3018            2    -0.016780
# 8  2021-02-05                0.0000            1    -0.000560
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-22               0.00000            1    -0.012123
# 1  2021-01-25               0.25530            2     0.016232
# 2  2021-01-26               0.00000            1    -0.016780
# 3  2021-01-27               0.06436            2    -0.008765
# 4  2021-01-28               0.00000            1    -0.012591
# 5  2021-01-29               0.00000            1    -0.018819
# 6  2021-02-01               0.00000            1     0.015286
# 7  2021-02-02               0.00000            1    -0.004405
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-10-16              0.000000            1     0.007951
# 1  2020-10-30              0.000000            1    -0.017463
# 2  2020-11-19              0.098667            2    -0.003917
# 3  2021-01-04              0.000000            1     0.014238
# 4  2021-01-20              0.296000            2     0.005641
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-09                 0.000            1    -0.005413
# 1  2021-01-15                 0.148            2     0.006321
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-11                   0.0            1     0.000007
# 1  2020-11-17                   0.0            1    -0.003771
# 2  2020-11-24                   0.0            1    -0.001582
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-05-13                0.4466            2     0.002846
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-09-17                   0.0            1    -0.013598
# 1  2020-09-23                   0.0            1     0.001746
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-13              0.790600            2    -0.002604
# 1  2021-01-19             -0.098667            0     0.018629
# 2  2021-01-22              0.025800            2    -0.012123
# 3  2021-01-25             -0.296000            0     0.016232
# 4  2021-01-26              0.323300            2    -0.016780
# 5  2021-01-27              0.000000            1    -0.008765
# 6  2021-01-28              0.000000            1    -0.012591
# 7  2021-02-01             -0.180400            0     0.015286
# 8  2021-02-05              0.440400            2    -0.000560
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-25                0.6739            2    -0.005601
# 1  2021-01-27                0.7739            2    -0.008765
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-08-20                0.5814            2    -0.010535
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-02-27                0.4466            2     0.009403
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# ...
# 2  2020-11-18                 0.000            1     0.004163
# 3  2020-11-30                 0.000            1    -0.019063
# 4  2020-12-21                 0.000            1    -0.004388
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-12                 0.000            1    -0.009086
# 1  2020-12-01                 0.296            2     0.005487
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-12-31                0.6289            2     0.001336
# 1  2021-01-12                0.4466            2     0.013711
# 2  2021-01-27                0.4466            2    -0.008765
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-10-22                 0.000            1     0.003637
# 1  2020-11-18                 0.296            2     0.004163
# 2  2020-11-30                 0.000            1    -0.019063
# 3  2020-12-21                 0.296            2    -0.004388
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-27               0.10115            2     0.005090
# 1  2020-12-31               0.29600            2     0.001336
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-09                   0.0            1    -0.005413
# 1  2021-01-14                   0.0            1     0.003124
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-12-18              0.408400            2    -0.005699
# 1  2020-12-23              0.000000            1     0.009968
# 2  2020-12-31              0.000000            1     0.001336
# 3  2021-01-28             -0.223300            0    -0.012591
# 4  2021-02-01              0.526400            2     0.015286
# 5  2021-02-02             -0.098667            0    -0.004405
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-07               0.24120            2    -0.006041
# 1  2021-01-11               0.00000            1    -0.003420
# 2  2021-01-12               0.00000            1     0.013711
# 3  2021-01-15               0.23835            2     0.006321
# 4  2021-01-22               0.00000            1    -0.012123
# 5  2021-01-27               0.00000            1    -0.008765
# 6  2021-02-02               0.00000            1    -0.004405
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-10-20               0.34700            2    -0.000086
# 1  2020-11-25               0.29600            2    -0.005601
# 2  2020-11-26               0.00000            1     0.004652
# 3  2020-12-02               0.00000            1    -0.005157
# 4  2020-12-11               0.29600            2    -0.004819
# 5  2020-12-16               0.45880            2     0.001479
# 6  2021-01-21               0.00000            1    -0.000802
# 7  2021-02-03               0.00000            1     0.000070
# 8  2021-02-04              -0.36120            0     0.000686
# 9  2021-02-05              -0.39135            0    -0.000560
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-09-15                 0.296            2     0.004513
# 1  2021-01-29                 0.000            1    -0.018819
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-12-04              0.482400            2     0.000907
# 1  2020-12-08              0.000000            1    -0.005888
# 2  2020-12-31              0.000000            1     0.001336
# 3  2021-01-11              0.000000            1    -0.003420
# 4  2021-01-12              0.000000            1     0.013711
# 5  2021-01-25              0.098667            2     0.016232
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-25                0.6037            2     0.016232
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-11-03                 0.000            1     0.010133
# 1  2020-11-19                 0.000            1    -0.003917
# 2  2020-11-20                 0.296            2     0.001692
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-07-24                 0.296            2    -0.013395
# 1  2020-11-11                 0.296            2     0.000007
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-12-31              0.000000            1     0.001336
# 1  2021-01-12              0.000000            1     0.013711
# 2  2021-01-25              0.276467            2     0.016232
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2020-05-21                0.4278            2    -0.010146
# 1  2020-06-04                0.2960            2    -0.011262
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-12                 0.296            2     0.013711
# 1  2021-01-19                 0.000            1     0.018629
# 2  2021-01-25                 0.000            1     0.016232
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-19                   0.0            1     0.018629
# 1  2021-02-01                   0.0            1     0.015286
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-19                   0.0            1     0.018629
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-25                   0.0            1     0.016232
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-19                   0.0            1     0.018629
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-21                   0.0            1    -0.000802
# 1  2021-01-27                   0.0            1    -0.008765
# 2  2021-02-02                   0.0            1    -0.004405
# 3  2021-02-03                   0.0            1     0.000070
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-19                   0.0            1     0.018629
# 1  2021-01-25                   0.0            1     0.016232
# 2  2021-02-01                   0.0            1     0.015286
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-26                   0.0            1     -0.01678
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-26                   0.0            1     -0.01678
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
#         dates  compound_vader_score  vader_label  hsi_average
# 0  2021-01-26                   0.0            1     -0.01678
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
# read in datasets
# find_pred_label
# merge_actual_label
# Empty DataFrame
# Columns: [dates, compound_vader_score, vader_label, hsi_average]
# Index: []
